# %%
from dotenv import load_dotenv
import os

import pandas as pd
from openai import OpenAI

from tqdm import tqdm
from sklearn.metrics import accuracy_score, classification_report

# %%
load_dotenv()
# Out:
# True

# %%
test = pd.read_csv('../csv/tweet-sentiment-test.csv')[0:300]
test
# Out:
#                                                  Tweet    Label
# 0    Üç kaynakta da bu geminin tüm gemilerin en iyi...     Nötr
# 1    işlemci olarak snapdragon 615, grafik adreno 4...  Pozitif
# 2     berbat..iğrenç.yazık... bu tarz 1000 tane fıl...  Negatif
# 3                        Bir süre Selanik’te bulundu .     Nötr
# 4                Dönem milletvekillerinden biri oldu .     Nötr
# ..                                                 ...      ...
# 295     Ses cok berbat ve rahat degil, önermem kimseye  Negatif
# 296  siparişim horoz lojistlik tarafından 2. gün ta...  Pozitif
# 297  Bu özelliğiyle dünyadaki birçok milliyetçi har...     Nötr
# 298  babam bu telefonu alalı daha 1 ay olmuyor. sad...  Negatif
# 299  merhaba, hızlı teslimatı, çok kaliteli ve kull...  Pozitif
#
# [300 rows x 2 columns]

# %%
client = OpenAI(
    api_key=os.getenv('API_KEY'),
)


def classify_text(dataset):

    i = 0
    predictions = []
    while i < dataset.shape[0]:

        try:

            message = dataset.iloc[i]["Tweet"]
            prompt = f"""Do sentiment analysis of input text and return 3 labels: "Pozitif", "Nötr", "Negatif" Message: '{message}'.
The output should only contain one of the five words: "Pozitif", "Nötr" or "Negatif"
"""
            chat_completion = client.chat.completions.create(
                messages=[
                    {"role": "user", "content": prompt}
                ],
                model="gpt-3.5-turbo",
            )

            response =  chat_completion.choices[0].message.content
            predictions.append(response)

        except Exception as err:
            print(err)

        
        i = i + 1
        print(f"Total messages processed: {i}")
    return predictions

# %%
predictions = classify_text(test)
# Out:
# Total messages processed: 1
# Total messages processed: 2
# Total messages processed: 3
# Total messages processed: 4
# Total messages processed: 5
# Total messages processed: 6
# Total messages processed: 7
# Total messages processed: 8
# Total messages processed: 9
# Total messages processed: 10
# Total messages processed: 11
# Total messages processed: 12
# Total messages processed: 13
# Total messages processed: 14
# Total messages processed: 15
# Total messages processed: 16
# Total messages processed: 17
# Total messages processed: 18
# Total messages processed: 19
# Total messages processed: 20
# Total messages processed: 21
# Total messages processed: 22
# Total messages processed: 23
# Total messages processed: 24
# Total messages processed: 25
# Total messages processed: 26
# Total messages processed: 27
# Total messages processed: 28
# Total messages processed: 29
# Total messages processed: 30
# Total messages processed: 31
# Total messages processed: 32
# Total messages processed: 33
# Total messages processed: 34
# Total messages processed: 35
# Total messages processed: 36
# Total messages processed: 37
# Total messages processed: 38
# Total messages processed: 39
# Total messages processed: 40
# Total messages processed: 41
# Total messages processed: 42
# Total messages processed: 43
# Total messages processed: 44
# Total messages processed: 45
# Total messages processed: 46
# Total messages processed: 47
# Total messages processed: 48
# Total messages processed: 49
# Total messages processed: 50
# Total messages processed: 51
# Total messages processed: 52
# Total messages processed: 53
# Total messages processed: 54
# Total messages processed: 55
# Total messages processed: 56
# Total messages processed: 57
# Total messages processed: 58
# Total messages processed: 59
# Total messages processed: 60
# Total messages processed: 61
# Total messages processed: 62
# Total messages processed: 63
# Total messages processed: 64
# Total messages processed: 65
# Total messages processed: 66
# Total messages processed: 67
# Total messages processed: 68
# Total messages processed: 69
# Total messages processed: 70
# Total messages processed: 71
# Total messages processed: 223
# Total messages processed: 224
# Total messages processed: 225
# Total messages processed: 226
# Total messages processed: 227
# Total messages processed: 228
# Total messages processed: 229
# Total messages processed: 230
# Total messages processed: 231
# Total messages processed: 232
# Total messages processed: 233
# Total messages processed: 234
# Total messages processed: 235
# Total messages processed: 236
# Total messages processed: 237
# Total messages processed: 238
# Total messages processed: 239
# Total messages processed: 240
# Total messages processed: 241
# Total messages processed: 242
# Total messages processed: 243
# Total messages processed: 244
# Total messages processed: 245
# Total messages processed: 246
# Total messages processed: 247
# Total messages processed: 248
# Total messages processed: 249
# Total messages processed: 250
# Total messages processed: 251
# Total messages processed: 252
# Total messages processed: 253
# Total messages processed: 254
# Total messages processed: 255
# Total messages processed: 256
# Total messages processed: 257
# Total messages processed: 258
# Total messages processed: 259
# Total messages processed: 260
# Total messages processed: 261
# Total messages processed: 262
# Total messages processed: 263
# Total messages processed: 264
# Total messages processed: 265
# Total messages processed: 266
# Total messages processed: 267
# Total messages processed: 268
# Total messages processed: 269
# Total messages processed: 270
# Total messages processed: 271
# Total messages processed: 272
# Total messages processed: 273
# Total messages processed: 274
# Total messages processed: 275
# Total messages processed: 276
# Total messages processed: 277
# Total messages processed: 278
# Total messages processed: 279
# Total messages processed: 280
# Total messages processed: 281
# Total messages processed: 282
# Total messages processed: 283
# Total messages processed: 284
# Total messages processed: 285
# Total messages processed: 286
# Total messages processed: 287
# Total messages processed: 288
# Total messages processed: 289
# Total messages processed: 290
# Total messages processed: 291
# Total messages processed: 292
# Total messages processed: 293
# Total messages processed: 294
# Total messages processed: 295
# Total messages processed: 296
# Total messages processed: 297
# Total messages processed: 298
# Total messages processed: 299
# Total messages processed: 300

# %%
to_set = set(predictions)
to_set
# Out:
# {'"Pozitif"',
#  "'Negatif'",
#  'Negatif',
#  'Negatif.',
#  'Nötr',
#  'Pozitif',
#  'Pozitif.',
#  'The sentiment analysis of the input text indicates a "Negatif" label.'}

# %%
pred_df = pd.DataFrame(predictions, columns=['Label'])
pred_df.head(10)
# Out:
#      Label
# 0  Pozitif
# 1  Pozitif
# 2  Negatif
# 3     Nötr
# 4     Nötr
# 5  Negatif
# 6  Pozitif
# 7  Negatif
# 8     Nötr
# 9  Pozitif

# %%
def change_label(label):
    if 'Pozitif' in label:
        return 2
    elif 'Nötr' in label:
        return 1
    elif 'Negatif' in label:
        return 0

# %%
pred_df['Label'] = pred_df['Label'].map(change_label)
pred_df
# Out:
#      Label
# 0        2
# 1        2
# 2        0
# 3        1
# 4        1
# ..     ...
# 295      0
# 296      2
# 297      2
# 298      0
# 299      2
#
# [300 rows x 1 columns]

# %%
test['Label'] = test['Label'].map({'Negatif': 0, 'Nötr': 1, 'Pozitif': 2})

# %%
pred_df[pred_df['Label'].isna()]
# Out:
# Empty DataFrame
# Columns: [Label]
# Index: []

# %%
print(classification_report(pred_df['Label'].values, test['Label'].values))
print(accuracy_score(pred_df['Label'].values, test['Label'].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.84       110
#            1       0.77      0.92      0.84        86
#            2       0.84      0.82      0.83       104
#
#     accuracy                           0.84       300
#    macro avg       0.84      0.84      0.84       300
# weighted avg       0.84      0.84      0.84       300
#
# 0.8366666666666667

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

sns.heatmap(confusion_matrix(pred_df['Label'].values, test['Label'].values),annot = True,fmt='d')
# Out:
# <Axes: >
